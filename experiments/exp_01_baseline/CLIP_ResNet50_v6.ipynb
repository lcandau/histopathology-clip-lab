# %% [markdown]
# # Imports and GPU setup

# %% [markdown]
# We need to install the latests versions of keras-hub and tensorflow to have access to tools like the Backbone keras models.

# %%
# Run this in a fresh runtime, before importing tensorflow / keras / keras_hub
# !pip uninstall -y tensorflow tensorflow-text keras keras-hub tf-keras
# !pip install -U tensorflow tensorflow-text keras keras-hub
# !pip install -q umap-learn
# Out:
# Found existing installation: tensorflow 2.20.0
# Uninstalling tensorflow-2.20.0:
#   Successfully uninstalled tensorflow-2.20.0
# Found existing installation: tensorflow-text 2.20.1
# Uninstalling tensorflow-text-2.20.1:
#   Successfully uninstalled tensorflow-text-2.20.1
# Found existing installation: keras 3.14.0
# Uninstalling keras-3.14.0:
#   Successfully uninstalled keras-3.14.0
# Found existing installation: keras-hub 0.28.0
# Uninstalling keras-hub-0.28.0:
#   Successfully uninstalled keras-hub-0.28.0
# WARNING: Skipping tf-keras as it is not installed.
# Collecting tensorflow
#   Using cached tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Collecting tensorflow-text
#   Using cached tensorflow_text-2.20.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting keras
#   Using cached keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting keras-hub
#   Using cached keras_hub-0.28.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.0)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Using cached protobuf-7.34.1-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Using cached h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras) (0.19.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from keras-hub) (2025.11.3)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (from keras-hub) (1.0.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from keras-hub) (0.2.1)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from keras-hub) (0.22.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-hub) (0.1.18)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-hub) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-hub) (4.67.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (2.20.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->keras-hub) (1.10.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (0.24.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (0.0.4)
# Using cached tensorflow_text-2.20.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (62.5 MB)
# Using cached tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (620.7 MB)
# Using cached keras-3.14.0-py3-none-any.whl (1.6 MB)
# Using cached keras_hub-0.28.0-py3-none-any.whl (1.5 MB)
# Installing collected packages: keras, tensorflow, tensorflow-text, keras-hub
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.12.0 requires tf_keras~=2.19, which is not installed.
# dopamine-rl 4.1.2 requires tf-keras>=2.18.0, which is not installed.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.20.0 which is incompatible.
# keras-nlp 0.26.0 requires keras-hub==0.26.0, but you have keras-hub 0.28.0 which is incompatible.
# Successfully installed keras-3.14.0 keras-hub-0.28.0 tensorflow-2.20.0 tensorflow-text-2.20.1

# %%
# Imports needed to run this notebook
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import json
from pathlib import Path
from PIL import Image

# Dataset download imports
from google.colab import drive
import kagglehub

# ML imports
import tensorflow as tf
import keras
import keras_hub
from keras.utils import plot_model
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer

import umap
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score

# %% [markdown]
# Check and setup GPU if present:

# %%
gpus = tf.config.list_physical_devices("GPU")
print("GPUs:", gpus)

strategy = tf.distribute.MirroredStrategy() if len(gpus) > 1 else tf.distribute.get_strategy()
print("Strategy:", type(strategy).__name__)
# Out:
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Strategy: _DefaultDistributionStrategy

# %% [markdown]
# Configuration fields for the model and trainning

# %%
# Model & training
IMG_SIZE = 224
MAX_LEN = 16
EMBED_DIM = 256
BATCH_SIZE = 8
EPOCHS = 10
LR = 1e-5
WD = 1e-4

# Performance
AUTOTUNE = tf.data.AUTOTUNE

# Reproducibility
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %% [markdown]
# # Downloading and preparing the dataset

# %% [markdown]
# Lets load the input dataset chosen, a **lung and colon cancer** *histopathological image* dataset: https://arxiv.org/pdf/1912.12142v1
#
# This dataset contains 25,000 histopathological images, patches of Whole Slide Images (WSI) for lung and colon tissues. All images are 768 x 768 pixels in size and are in jpeg file format.
#
# Images are categorized in 5 classes:
# - Lung bening tisues
# - Lung adenocarcinoma
# - Lung squamous cell carcinoma
# - Colon bening tissue
# - Colon adenocarcinoma

# %% [markdown]
# ## Download the dataset

# %%
# Download latest version
path = kagglehub.dataset_download("andrewmvd/lung-and-colon-cancer-histopathological-images")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'lung-and-colon-cancer-histopathological-images' dataset.
# Path to dataset files: /kaggle/input/lung-and-colon-cancer-histopathological-images

# %% [markdown]
# After exploring the downloaded dataset, lets load it:

# %%
base_dir = path + "/lung_colon_image_set"

CLASS_INFO = [
    {
        "id": "lung_n",
        "subdir": "lung_image_sets/lung_n",
        "name": "benign lung tissue",
    },
    {
        "id": "lung_aca",
        "subdir": "lung_image_sets/lung_aca",
        "name": "lung adenocarcinoma",
    },
    {
        "id": "lung_scc",
        "subdir": "lung_image_sets/lung_scc",
        "name": "lung squamous cell carcinoma",
    },
    {
        "id": "colon_n",
        "subdir": "colon_image_sets/colon_n",
        "name": "benign colon tissue",
    },
    {
        "id": "colon_aca",
        "subdir": "colon_image_sets/colon_aca",
        "name": "colon adenocarcinoma",
    },
]

# %%
PROMPT_TEMPLATES = [
    "A histopathology image of {}.",
    "An H&E stained tissue image showing {}.",
    "A microscopic pathology image of {}.",
    "A pathology slide region containing {}.",
    "A tissue sample consistent with {}.",
]

# %%
class_ids = [c["id"] for c in CLASS_INFO]
class_names = [c["name"] for c in CLASS_INFO]
class_dirs = [os.path.join(base_dir, c["subdir"]) for c in CLASS_INFO]

index_to_name = {i: c["name"] for i, c in enumerate(CLASS_INFO)}
index_to_id = {i: c["id"] for i, c in enumerate(CLASS_INFO)}

id_to_name = {c["id"]: c["name"] for c in CLASS_INFO}
id_to_index = {c["id"]: i for i, c in enumerate(CLASS_INFO)}

name_to_id = {c["name"]: c["id"] for c in CLASS_INFO}
name_to_index = {c["name"]: i for i, c in enumerate(CLASS_INFO)}

#print("class_ids: {}", class_ids)
#print("class_names: {}", class_names)
#print("class_dirs: {}", class_dirs)
#print("index_to_name: {}", index_to_name)
#print("index_to_id: {}", index_to_id)
#print("name_to_id: {}", name_to_id)
#print("name_to_index: {}", name_to_index)
#print("id_to_name: {}", id_to_name)
#print("id_to_index: {}", id_to_index)

# %% [markdown]
# **Assumptions taken:**
#
# - All images of the dataset have the same shape
# - All images loaded are JPEG format
# - Each image on each directory contains sufficient information for an AI model to deduce the class of the image

# %% [markdown]
# Lets now check the images loaded to learn the dataset's structure

# %%
# Validate shape of images loaded
sample_imgage = os.listdir(class_dirs[0])[0]
sample_path = os.path.join(class_dirs[0], sample_imgage)

with Image.open(sample_path) as img:
    sample = np.array(img)

print(sample.shape)
# Out:
# (768, 768, 3)

# %%
# Validate images loaded per class

images_per_class = [len(os.listdir(d)) for d in class_dirs]
total_images = sum(images_per_class)

print("Images per class:", images_per_class)
print("Total images:", total_images)
# Out:
# Images per class: [5000, 5000, 5000, 5000, 5000]
# Total images: 25000

# %%
records = []
labels = []

for class_idx, class_info in enumerate(CLASS_INFO):
    dir_path = os.path.join(base_dir, class_info["subdir"])

    for fname in sorted(os.listdir(dir_path)):
        if fname.lower().endswith((".jpg", ".jpeg")):
            records.append(os.path.join(dir_path, fname))
            labels.append(class_idx)

records = np.array(records)
labels = np.array(labels)

# %% [markdown]
# ## Visualize the dataset

# %%
idx = np.random.randint(len(records))
print(records[idx])
print(labels[idx])
# Out:
# /kaggle/input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/colon_image_sets/colon_aca/colonca4288.jpeg
# 4

# %%
# Helper function to visualize the images and labels of the dataset
def show_sample(records, labels, index):
    if index < 0 or index >= len(records):
        raise IndexError(f"Index {index} out of range (0 - {len(records)-1})")

    img_path, label = records[index], index_to_name[labels[index]]
    img = Image.open(img_path).convert("RGB")

    plt.figure(figsize=(5,5))
    plt.imshow(img)
    plt.title(f"Description: {label}", fontsize=12)
    plt.axis("off")
    plt.show()

# %%
idx1, idx2 = np.random.randint(len(records)), np.random.randint(len(records))
show_sample(records, labels, idx1)
show_sample(records, labels, idx2)

# %% [markdown]
# ❗❗❗ Warning:
#
# We can already tell by viewing the images that staining is likely an issue in this dataset, as the different tissue samples have different stain colorings.

# %% [markdown]
# # Model

# %% [markdown]
# We will be using the CLIP model (Contrastive Language-Image Pre-training), https://openai.com/index/clip/. This model is able to learn from text-images pairs, creating a shared embedding space for both. It is considered a foundational model and used on tasks such as zero-shot classification or image retrieval.

# %% [markdown]
# CLIP requires 2 backbone models, a image and a text model.
#
# **Image backbone**: We will be using [**ResNet50**](https://arxiv.org/abs/1512.03385) as the image model, a well-known CNN architecture that leverages skip connections to allow information to flow more easily across layers. This design helps mitigate the vanishing gradient problem in deep networks, enabling the training of much deeper models. ResNet achieved very strong results in the ImageNet challenge and has since become a standard backbone for many computer vision tasks. Therefore, we will use the pretrained version available in Keras Hub, initialized with ImageNet weights (`resnet_50_imagenet preset`).
#
# **Text backbone**: We will use a pretrained [**BERT**](https://arxiv.org/abs/1810.04805) (Bidirectional Encoder Representations from Transformers) model for the text backbone. BERT is a widely used language model introduced by Google AI in 2018, designed to process text bidirectionally, meaning it can learn contextual relationships between words by considering both left and right context simultaneously. It relies on the transformer encoder architecture to generate rich semantic representations of text. In the context of CLIP, we will leverage BERT to encode the textual descriptions into dense feature embeddings that can be aligned with the image embeddings produced by the ResNet50 backbone. This will allow the model to learn a shared embedding space where semantically related images and text are close to each other in the embedding space. We will use the pretrainned version of the BERT base model, available in keras_hub (`bert_base_en_uncased` preset). We will also define the BERT preprocesor to tokenize the description strings for BERT to generate embeddings.

# %% [markdown]
# ## Define the model

# %% [markdown]
# Define the text and image backbone models. Freeze them initially.

# %%
image_backbone = keras_hub.models.Backbone.from_preset("resnet_50_imagenet")
text_backbone = keras_hub.models.Backbone.from_preset("bert_base_en_uncased")
text_preprocessor = keras_hub.models.BertTextClassifierPreprocessor.from_preset(
    "bert_base_en_uncased",
    sequence_length=MAX_LEN,
)

image_backbone.trainable = True
for layer in image_backbone.layers[:-30]:
    layer.trainable = False
text_backbone.trainable = False

# %%
# Visualize the model

image_backbone.summary()
text_backbone.summary()
plot_model(image_backbone, show_shapes=True, expand_nested=True)
plot_model(text_backbone, show_shapes=True, expand_nested=True)
# Out:
# Model: "res_net_backbone"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, None,      │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, None,      │      9,408 │ conv1_pad[0][0]   │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, None,      │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, None,      │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, None,      │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, None,      │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_1_co… │ (None, None,      │      4,096 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_1_bn  │ (None, None,      │        256 │ stack0_block0_1_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_1_re… │ (None, None,      │          0 │ stack0_block0_1_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_2_co… │ (None, None,      │     36,864 │ stack0_block0_1_… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_2_bn  │ (None, None,      │        256 │ stack0_block0_2_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_2_re… │ (None, None,      │          0 │ stack0_block0_2_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_0_co… │ (None, None,      │     16,384 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_3_co… │ (None, None,      │     16,384 │ stack0_block0_2_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_0_bn  │ (None, None,      │      1,024 │ stack0_block0_0_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_3_bn  │ (None, None,      │      1,024 │ stack0_block0_3_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_add   │ (None, None,      │          0 │ stack0_block0_0_… │
# │ (Add)               │ None, 256)        │            │ stack0_block0_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_out   │ (None, None,      │          0 │ stack0_block0_ad… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_1_co… │ (None, None,      │     16,384 │ stack0_block0_ou… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_1_bn  │ (None, None,      │        256 │ stack0_block1_1_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_1_re… │ (None, None,      │          0 │ stack0_block1_1_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_2_co… │ (None, None,      │     36,864 │ stack0_block1_1_… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_2_bn  │ (None, None,      │        256 │ stack0_block1_2_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_2_re… │ (None, None,      │          0 │ stack0_block1_2_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_3_co… │ (None, None,      │     16,384 │ stack0_block1_2_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_3_bn  │ (None, None,      │      1,024 │ stack0_block1_3_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_add   │ (None, None,      │          0 │ stack0_block0_ou… │
# │ (Add)               │ None, 256)        │            │ stack0_block1_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_out   │ (None, None,      │          0 │ stack0_block1_ad… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_1_co… │ (None, None,      │     16,384 │ stack0_block1_ou… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_1_bn  │ (None, None,      │        256 │ stack0_block2_1_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_1_re… │ (None, None,      │          0 │ stack0_block2_1_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_2_co… │ (None, None,      │     36,864 │ stack0_block2_1_… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_2_bn  │ (None, None,      │        256 │ stack0_block2_2_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_2_re… │ (None, None,      │          0 │ stack0_block2_2_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_3_co… │ (None, None,      │     16,384 │ stack0_block2_2_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_3_bn  │ (None, None,      │      1,024 │ stack0_block2_3_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_add   │ (None, None,      │          0 │ stack0_block1_ou… │
# │ (Add)               │ None, 256)        │            │ stack0_block2_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_out   │ (None, None,      │          0 │ stack0_block2_ad… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_1_co… │ (None, None,      │     32,768 │ stack0_block2_ou… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_1_bn  │ (None, None,      │        512 │ stack1_block0_1_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_1_re… │ (None, None,      │          0 │ stack1_block0_1_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_2_pad │ (None, None,      │          0 │ stack1_block0_1_… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_2_co… │ (None, None,      │    147,456 │ stack1_block0_2_… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_2_bn  │ (None, None,      │        512 │ stack1_block0_2_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_2_re… │ (None, None,      │          0 │ stack1_block0_2_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_0_co… │ (None, None,      │    131,072 │ stack0_block2_ou… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_3_co… │ (None, None,      │     65,536 │ stack1_block0_2_… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_0_bn  │ (None, None,      │      2,048 │ stack1_block0_0_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_3_bn  │ (None, None,      │      2,048 │ stack1_block0_3_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_add   │ (None, None,      │          0 │ stack1_block0_0_… │
# │ (Add)               │ None, 512)        │            │ stack1_block0_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_out   │ (None, None,      │          0 │ stack1_block0_ad… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_1_co… │ (None, None,      │     65,536 │ stack1_block0_ou… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_1_bn  │ (None, None,      │        512 │ stack1_block1_1_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_1_re… │ (None, None,      │          0 │ stack1_block1_1_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_2_co… │ (None, None,      │    147,456 │ stack1_block1_1_… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_2_bn  │ (None, None,      │        512 │ stack1_block1_2_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_2_re… │ (None, None,      │          0 │ stack1_block1_2_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_3_co… │ (None, None,      │     65,536 │ stack1_block1_2_… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_3_bn  │ (None, None,      │      2,048 │ stack1_block1_3_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_add   │ (None, None,      │          0 │ stack1_block0_ou… │
# │ (Add)               │ None, 512)        │            │ stack1_block1_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_out   │ (None, None,      │          0 │ stack1_block1_ad… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_1_co… │ (None, None,      │     65,536 │ stack1_block1_ou… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_1_bn  │ (None, None,      │        512 │ stack1_block2_1_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_1_re… │ (None, None,      │          0 │ stack1_block2_1_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_2_co… │ (None, None,      │    147,456 │ stack1_block2_1_… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_2_bn  │ (None, None,      │        512 │ stack1_block2_2_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_2_re… │ (None, None,      │          0 │ stack1_block2_2_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_3_co… │ (None, None,      │     65,536 │ stack1_block2_2_… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_3_bn  │ (None, None,      │      2,048 │ stack1_block2_3_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_add   │ (None, None,      │          0 │ stack1_block1_ou… │
# │ (Add)               │ None, 512)        │            │ stack1_block2_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_out   │ (None, None,      │          0 │ stack1_block2_ad… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_1_co… │ (None, None,      │     65,536 │ stack1_block2_ou… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_1_bn  │ (None, None,      │        512 │ stack1_block3_1_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_1_re… │ (None, None,      │          0 │ stack1_block3_1_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_2_co… │ (None, None,      │    147,456 │ stack1_block3_1_… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_2_bn  │ (None, None,      │        512 │ stack1_block3_2_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_2_re… │ (None, None,      │          0 │ stack1_block3_2_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_3_co… │ (None, None,      │     65,536 │ stack1_block3_2_… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_3_bn  │ (None, None,      │      2,048 │ stack1_block3_3_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_add   │ (None, None,      │          0 │ stack1_block2_ou… │
# │ (Add)               │ None, 512)        │            │ stack1_block3_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_out   │ (None, None,      │          0 │ stack1_block3_ad… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_1_co… │ (None, None,      │    131,072 │ stack1_block3_ou… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_1_bn  │ (None, None,      │      1,024 │ stack2_block0_1_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_1_re… │ (None, None,      │          0 │ stack2_block0_1_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_2_pad │ (None, None,      │          0 │ stack2_block0_1_… │
# │ (ZeroPadding2D)     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_2_co… │ (None, None,      │    589,824 │ stack2_block0_2_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_2_bn  │ (None, None,      │      1,024 │ stack2_block0_2_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_2_re… │ (None, None,      │          0 │ stack2_block0_2_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_0_co… │ (None, None,      │    524,288 │ stack1_block3_ou… │
# │ (Conv2D)            │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_3_co… │ (None, None,      │    262,144 │ stack2_block0_2_… │
# │ (Conv2D)            │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_0_bn  │ (None, None,      │      4,096 │ stack2_block0_0_… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_3_bn  │ (None, None,      │      4,096 │ stack2_block0_3_… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_add   │ (None, None,      │          0 │ stack2_block0_0_… │
# │ (Add)               │ None, 1024)       │            │ stack2_block0_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_out   │ (None, None,      │          0 │ stack2_block0_ad… │
# │ (Activation)        │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_1_co… │ (None, None,      │    262,144 │ stack2_block0_ou… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_1_bn  │ (None, None,      │      1,024 │ stack2_block1_1_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_1_re… │ (None, None,      │          0 │ stack2_block1_1_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_2_co… │ (None, None,      │    589,824 │ stack2_block1_1_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_2_bn  │ (None, None,      │      1,024 │ stack2_block1_2_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_2_re… │ (None, None,      │          0 │ stack2_block1_2_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_3_co… │ (None, None,      │    262,144 │ stack2_block1_2_… │
# │ (Conv2D)            │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_3_bn  │ (None, None,      │      4,096 │ stack2_block1_3_… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_add   │ (None, None,      │          0 │ stack2_block0_ou… │
# │ (Add)               │ None, 1024)       │            │ stack2_block1_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_out   │ (None, None,      │          0 │ stack2_block1_ad… │
# │ (Activation)        │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_1_co… │ (None, None,      │    262,144 │ stack2_block1_ou… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_1_bn  │ (None, None,      │      1,024 │ stack2_block2_1_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_1_re… │ (None, None,      │          0 │ stack2_block2_1_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_2_co… │ (None, None,      │    589,824 │ stack2_block2_1_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_2_bn  │ (None, None,      │      1,024 │ stack2_block2_2_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_2_re… │ (None, None,      │          0 │ stack2_block2_2_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_3_co… │ (None, None,      │    262,144 │ stack2_block2_2_… │
# │ (Conv2D)            │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_3_bn  │ (None, None,      │      4,096 │ stack2_block2_3_… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_add   │ (None, None,      │          0 │ stack2_block1_ou… │
# │ (Add)               │ None, 1024)       │            │ stack2_block2_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_out   │ (None, None,      │          0 │ stack2_block2_ad… │
# │ (Activation)        │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_1_co… │ (None, None,      │    262,144 │ stack2_block2_ou… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_1_bn  │ (None, None,      │      1,024 │ stack2_block3_1_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_1_re… │ (None, None,      │          0 │ stack2_block3_1_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_2_co… │ (None, None,      │    589,824 │ stack2_block3_1_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_2_bn  │ (None, None,      │      1,024 │ stack2_block3_2_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_2_re… │ (None, None,      │          0 │ stack2_block3_2_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_3_co… │ (None, None,      │    262,144 │ stack2_block3_2_… │
# │ (Conv2D)            │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_3_bn  │ (None, None,      │      4,096 │ stack2_block3_3_… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_add   │ (None, None,      │          0 │ stack2_block2_ou… │
# │ (Add)               │ None, 1024)       │            │ stack2_block3_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_out   │ (None, None,      │          0 │ stack2_block3_ad… │
# │ (Activation)        │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_1_co… │ (None, None,      │    262,144 │ stack2_block3_ou… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_1_bn  │ (None, None,      │      1,024 │ stack2_block4_1_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_1_re… │ (None, None,      │          0 │ stack2_block4_1_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_2_co… │ (None, None,      │    589,824 │ stack2_block4_1_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_2_bn  │ (None, None,      │      1,024 │ stack2_block4_2_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_2_re… │ (None, None,      │          0 │ stack2_block4_2_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_3_co… │ (None, None,      │    262,144 │ stack2_block4_2_… │
# │ (Conv2D)            │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_3_bn  │ (None, None,      │      4,096 │ stack2_block4_3_… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_add   │ (None, None,      │          0 │ stack2_block3_ou… │
# │ (Add)               │ None, 1024)       │            │ stack2_block4_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_out   │ (None, None,      │          0 │ stack2_block4_ad… │
# │ (Activation)        │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_1_co… │ (None, None,      │    262,144 │ stack2_block4_ou… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_1_bn  │ (None, None,      │      1,024 │ stack2_block5_1_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_1_re… │ (None, None,      │          0 │ stack2_block5_1_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_2_co… │ (None, None,      │    589,824 │ stack2_block5_1_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_2_bn  │ (None, None,      │      1,024 │ stack2_block5_2_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_2_re… │ (None, None,      │          0 │ stack2_block5_2_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_3_co… │ (None, None,      │    262,144 │ stack2_block5_2_… │
# │ (Conv2D)            │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_3_bn  │ (None, None,      │      4,096 │ stack2_block5_3_… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_add   │ (None, None,      │          0 │ stack2_block4_ou… │
# │ (Add)               │ None, 1024)       │            │ stack2_block5_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_out   │ (None, None,      │          0 │ stack2_block5_ad… │
# │ (Activation)        │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_1_co… │ (None, None,      │    524,288 │ stack2_block5_ou… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_1_bn  │ (None, None,      │      2,048 │ stack3_block0_1_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_1_re… │ (None, None,      │          0 │ stack3_block0_1_… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_2_pad │ (None, None,      │          0 │ stack3_block0_1_… │
# │ (ZeroPadding2D)     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_2_co… │ (None, None,      │  2,359,296 │ stack3_block0_2_… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_2_bn  │ (None, None,      │      2,048 │ stack3_block0_2_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_2_re… │ (None, None,      │          0 │ stack3_block0_2_… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_0_co… │ (None, None,      │  2,097,152 │ stack2_block5_ou… │
# │ (Conv2D)            │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_3_co… │ (None, None,      │  1,048,576 │ stack3_block0_2_… │
# │ (Conv2D)            │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_0_bn  │ (None, None,      │      8,192 │ stack3_block0_0_… │
# │ (BatchNormalizatio… │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_3_bn  │ (None, None,      │      8,192 │ stack3_block0_3_… │
# │ (BatchNormalizatio… │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_add   │ (None, None,      │          0 │ stack3_block0_0_… │
# │ (Add)               │ None, 2048)       │            │ stack3_block0_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_out   │ (None, None,      │          0 │ stack3_block0_ad… │
# │ (Activation)        │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_1_co… │ (None, None,      │  1,048,576 │ stack3_block0_ou… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_1_bn  │ (None, None,      │      2,048 │ stack3_block1_1_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_1_re… │ (None, None,      │          0 │ stack3_block1_1_… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_2_co… │ (None, None,      │  2,359,296 │ stack3_block1_1_… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_2_bn  │ (None, None,      │      2,048 │ stack3_block1_2_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_2_re… │ (None, None,      │          0 │ stack3_block1_2_… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_3_co… │ (None, None,      │  1,048,576 │ stack3_block1_2_… │
# │ (Conv2D)            │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_3_bn  │ (None, None,      │      8,192 │ stack3_block1_3_… │
# │ (BatchNormalizatio… │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_add   │ (None, None,      │          0 │ stack3_block0_ou… │
# │ (Add)               │ None, 2048)       │            │ stack3_block1_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_out   │ (None, None,      │          0 │ stack3_block1_ad… │
# │ (Activation)        │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_1_co… │ (None, None,      │  1,048,576 │ stack3_block1_ou… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_1_bn  │ (None, None,      │      2,048 │ stack3_block2_1_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_1_re… │ (None, None,      │          0 │ stack3_block2_1_… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_2_co… │ (None, None,      │  2,359,296 │ stack3_block2_1_… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_2_bn  │ (None, None,      │      2,048 │ stack3_block2_2_… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_2_re… │ (None, None,      │          0 │ stack3_block2_2_… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_3_co… │ (None, None,      │  1,048,576 │ stack3_block2_2_… │
# │ (Conv2D)            │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_3_bn  │ (None, None,      │      8,192 │ stack3_block2_3_… │
# │ (BatchNormalizatio… │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_add   │ (None, None,      │          0 │ stack3_block1_ou… │
# │ (Add)               │ None, 2048)       │            │ stack3_block2_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_out   │ (None, None,      │          0 │ stack3_block2_ad… │
# │ (Activation)        │ None, 2048)       │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,561,152 (89.88 MB)
#  Trainable params: 14,439,424 (55.08 MB)
#  Non-trainable params: 9,121,728 (34.80 MB)
# Model: "bert_backbone"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ token_ids           │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ token_embedding     │ (None, None, 768) │ 23,440,896 │ token_ids[0][0]   │
# │ (ReversibleEmbeddi… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segment_ids         │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ position_embedding  │ (None, None, 768) │    393,216 │ token_embedding[… │
# │ (PositionEmbedding) │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segment_embedding   │ (None, None, 768) │      1,536 │ segment_ids[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embeddings_add      │ (None, None, 768) │          0 │ token_embedding[… │
# │ (Add)               │                   │            │ position_embeddi… │
# │                     │                   │            │ segment_embeddin… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embeddings_layer_n… │ (None, None, 768) │      1,536 │ embeddings_add[0… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embeddings_dropout  │ (None, None, 768) │          0 │ embeddings_layer… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ padding_mask        │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_0 │ (None, None, 768) │  7,087,872 │ embeddings_dropo… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_1 │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_2 │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_3 │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_4 │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_5 │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_6 │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_7 │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_8 │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_9 │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_… │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_layer_… │ (None, None, 768) │  7,087,872 │ transformer_laye… │
# │ (TransformerEncode… │                   │            │ padding_mask[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 768)       │          0 │ transformer_laye… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pooled_dense        │ (None, 768)       │    590,592 │ get_item[0][0]    │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 109,482,240 (417.64 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 109,482,240 (417.64 MB)

# %% [markdown]
# Define a custom model (Keras' model doesn't support ResNet image encoder).

# %%
class CLIPModel(keras.Model):
    def __init__(self, img_backbone, text_backbone, embed_dim=256, init_temp=0.1):
        super().__init__()
        # Store image and text backbone models
        self.img_backbone = img_backbone
        self.text_backbone = text_backbone

        # Projection layers to ensure embeddings dimensions of image and text models match
        self.img_projection = keras.layers.Dense(embed_dim, use_bias=False)
        self.text_projection = keras.layers.Dense(embed_dim, use_bias=False)

        self.img_projection = keras.Sequential([
            keras.layers.Dropout(0.2),
            keras.layers.Dense(embed_dim, use_bias=False),
            keras.layers.LayerNormalization(),
        ])

        self.text_projection = keras.Sequential([
            keras.layers.Dropout(0.2),
            keras.layers.Dense(embed_dim, use_bias=False),
            keras.layers.LayerNormalization(),
        ])

        # Configure temperature to try control distance between embedding clusters
        self.logit_scale = self.add_weight(
            name="logit_scale",
            shape=(),
            initializer=tf.keras.initializers.Constant(
                tf.math.log(1.0 / init_temp).numpy()
            ),
            trainable=True,
            dtype=tf.float32,
        )

        self.loss_tracker = keras.metrics.Mean(name="loss")

    @property
    def metrics(self):
        return [self.loss_tracker]

    def encode_image(self, images, training=False):
        backbone_training = training and self.img_backbone.trainable
        x = self.img_backbone(images, training=backbone_training)

        # Global average pooling
        if len(x.shape) == 4:
            x = tf.reduce_mean(x, axis=[1, 2])
        else:
            raise ValueError(f"Unexpected image backbone output shape: {x}")

        # Projection of image features into CLIP embeddings dimensions
        x = self.img_projection(x)
        # Normalization of the embeddings
        x = tf.math.l2_normalize(x, axis=-1)

        return x

    def encode_text(self, token_dict, training=False):
        backbone_training = training and self.text_backbone.trainable
        out = self.text_backbone(token_dict, training=backbone_training)

        if isinstance(out, dict):
            if "pooled_output" in out:
                # We expect the output of the BERT model to return this key
                x = out["pooled_output"]
            elif "sequence_output" in out:
                x = out["sequence_output"][:, 0, :]
            else:
                raise ValueError(f"Unexpected BERT output keys: {list(out.keys())}")
        else:
            if len(out.shape) == 3:
                x = out[:, 0, :]
            else:
                x = out

        # Projection of text features into CLIP embeddings dimensions
        x = self.text_projection(x)
        # Normalization of the embeddings
        x = tf.math.l2_normalize(x, axis=-1)

        return x

    def compute_clip_loss(self, img_emb, txt_emb):
        # 1 - Cast to float32 to avoid numeric instability (Do I need this?)
        img_emb = tf.cast(img_emb, tf.float32)
        txt_emb = tf.cast(txt_emb, tf.float32)

        # Keep trainable temperature within a safe range
        logit_scale = tf.exp(tf.clip_by_value(self.logit_scale, 0.0, tf.math.log(100.0)))

        # Matrix multiplication to get similarity matrix
        logits = tf.matmul(img_emb, txt_emb, transpose_b=True) * logit_scale
        logits = tf.clip_by_value(logits, -100.0, 100.0)

        labels = tf.range(tf.shape(logits)[0])

        # Compute two losses
        # Image -> text loss
        loss_i2t = tf.nn.sparse_softmax_cross_entropy_with_logits(
            labels=labels, logits=logits
        )
        # Text -> image loss
        loss_t2i = tf.nn.sparse_softmax_cross_entropy_with_logits(
            labels=labels, logits=tf.transpose(logits)
        )

        # Average of both loss values
        loss = 0.5 * (loss_i2t + loss_t2i)
        return tf.reduce_mean(loss)

    def train_step(self, data):
        images, token_dict = data

        with tf.GradientTape() as tape:
            img_emb = self.encode_image(images, training=True)
            txt_emb = self.encode_text(token_dict, training=True)
            loss = self.compute_clip_loss(img_emb, txt_emb)

        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.trainable_variables))

        self.loss_tracker.update_state(loss)
        return {
            "loss": self.loss_tracker.result(),
            "temperature": tf.exp(-self.logit_scale),
        }

    def test_step(self, data):
        images, token_dict = data
        img_emb = self.encode_image(images, training=False)
        txt_emb = self.encode_text(token_dict, training=False)
        loss = self.compute_clip_loss(img_emb, txt_emb)

        self.loss_tracker.update_state(loss)
        return {
            "loss": self.loss_tracker.result(),
            "temperature": tf.exp(-self.logit_scale),
        }

    def call(self, inputs, training=False):
        images, token_dict = inputs
        img_emb = self.encode_image(images, training=training)
        txt_emb = self.encode_text(token_dict, training=training)
        return {"image_embeddings": img_emb, "text_embeddings": txt_emb}

# %%
model = CLIPModel(image_backbone, text_backbone, embed_dim=EMBED_DIM)

optimizer = keras.optimizers.AdamW(
    learning_rate=LR,
    weight_decay=WD,
    global_clipnorm=1.0
)
model.compile(optimizer=optimizer)
model.summary()
# Out:
# Model: "clip_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ res_net_backbone                │ (None, None, None,     │    23,561,152 │
# │ (ResNetBackbone)                │ 2048)                  │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bert_backbone (BertBackbone)    │ ((None, 768), (None,   │   109,482,240 │
# │                                 │ None, 768))            │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 133,043,393 (507.52 MB)
#  Trainable params: 14,439,425 (55.08 MB)
#  Non-trainable params: 118,603,968 (452.44 MB)

# %% [markdown]
# ### Build the training, validation and test datasets

# %% [markdown]
# First we start by dividing the trainning dataset with a train / validate split of 80% - 20%. We build batches of `BATCH_SIZE` of the images & text to input to the model.
#
# *Note:* The LC25000 dataset has 25,000 images, but the paper states they are created from only 1,250 original images, then expanded using rotations and flips. So your effective diversity is much smaller than it looks and the dataset is already augmented - partly.

# %%
train_records, temp_records, train_labels, temp_labels = train_test_split(
    records,
    labels,
    test_size=0.2,
    random_state=SEED,
    stratify=labels
)

val_records, test_records, val_labels, test_labels = train_test_split(
    temp_records,
    temp_labels,
    test_size=0.5,
    random_state=SEED,
    stratify=temp_labels
)

print(len(train_records), len(val_records), len(test_records))
# Out:
# 20000 2500 2500

# %%
# Stain/color robustness augmentation for training
def augment_image(img):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)

    img = tf.image.random_brightness(img, max_delta=0.12)
    img = tf.image.random_contrast(img, lower=0.75, upper=1.35)
    img = tf.image.random_saturation(img, lower=0.75, upper=1.35)
    img = tf.image.random_hue(img, max_delta=0.03)

    img = tf.clip_by_value(img, 0.0, 255.0)
    return img

# %%
def load_image(path, training=False):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    img = tf.cast(img, tf.float32)

    if training:
        img = augment_image(img)

    img = keras.applications.resnet.preprocess_input(img)
    return img

# %% [markdown]
# **Build traning dataset:**

# %%
prompt_templates_tf = tf.constant(PROMPT_TEMPLATES)
class_names_tf = tf.constant(class_names)

def make_training_prompt(class_id):
    template_idx = tf.random.uniform(
        shape=[],
        minval=0,
        maxval=len(PROMPT_TEMPLATES),
        dtype=tf.int32
    )

    template = prompt_templates_tf[template_idx]
    class_name = class_names_tf[class_id]

    return tf.strings.regex_replace(template, r"\{\}", class_name)

# Build training and validation datasets from slices
def preprocess_training_example(img_path, class_id):
    image = load_image(img_path, training=True)
    text = make_training_prompt(class_id)
    token_dict = text_preprocessor(text)
    return image, token_dict

train_ds = tf.data.Dataset.from_tensor_slices((train_records, train_labels))
train_ds = train_ds.shuffle(len(train_records), seed=SEED)
train_ds = train_ds.map(preprocess_training_example, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.batch(BATCH_SIZE)
train_ds = train_ds.prefetch(AUTOTUNE)

# %% [markdown]
# **Build evaluation dataset**

# %%
def make_eval_prompt(class_id):
    return tf.strings.format(
        "A histopathology image of {}.",
        # Cast class_id to tf.int32 for indexing
        class_names_tf[tf.cast(class_id, tf.int32)]
    )

def preprocess_validation_example(img_path, class_id):
    image = load_image(img_path, training=False)
    text = make_eval_prompt(class_id)
    token_dict = text_preprocessor(text)
    return image, token_dict

val_ds = tf.data.Dataset.from_tensor_slices((val_records, val_labels))
val_ds = val_ds.map(preprocess_validation_example, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.batch(BATCH_SIZE)
val_ds = val_ds.prefetch(AUTOTUNE)

# %% [markdown]
# **Build test dataset**

# %%
def preprocess_eval_example(img_path, class_id):
    image = load_image(img_path, training=False)
    return image, class_id

test_ds = tf.data.Dataset.from_tensor_slices((test_records, test_labels))
test_ds = test_ds.map(preprocess_eval_example, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %% [markdown]
# ## Train the model

# %% [markdown]
# Lets explore the batches of the trainning dataset we built. The expectation is to have per bacth:
# - `BATCH_SIZE` images of `IMG_SIZE`x`IMG_SIZE`x3 size
# - `BATCH_SIZE` tokens of `MAX_LEN` size

# %%
batch = next(iter(train_ds))
images, token_dict = batch

print("Images:", images.shape, images.dtype)
print("Token keys:", token_dict.keys())
for k, v in token_dict.items():
    print(k, v.shape, v.dtype)
# Out:
# Images: (8, 224, 224, 3) <dtype: 'float32'>
# Token keys: dict_keys(['token_ids', 'padding_mask', 'segment_ids'])
# token_ids (8, 16) <dtype: 'int32'>
# padding_mask (8, 16) <dtype: 'bool'>
# segment_ids (8, 16) <dtype: 'int32'>

# %%
_ = model((images[:1], {k: v[:1] for k, v in token_dict.items()}), training=False)
print("Model built:", model.built)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:427: UserWarning: `build()` was called on layer 'clip_model', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Model built: True

# %%
# Quick test to see if the model correctly processes the images and texts into same size:
img_emb = model.encode_image(images[:2], training=False)
txt_emb = model.encode_text({k: v[:2] for k, v in token_dict.items()}, training=False)

print("Image embeddings:", img_emb.shape)
print("Text embeddings:", txt_emb.shape)
# Out:
# Image embeddings: (2, 256)
# Text embeddings: (2, 256)

# %%
# Quick test to see if the model can correctly take a trainning step with the input bactches of the dataset:

out = model.train_step(batch)
print("Loss - ", out["loss"])
print("Temperature - ", out["temperature"])
# Out:
# Loss -  tf.Tensor(2.1358244, shape=(), dtype=float32)
# Temperature -  tf.Tensor(0.100001, shape=(), dtype=float32)

# %% [markdown]
# CLIP model trainning:

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=2,
        restore_best_weights=True,
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2,
    ),
    keras.callbacks.ModelCheckpoint(
        "checkpoints/clip_resnet50_best.weights.h5",
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=True,
        mode="min",
        verbose=1,
    ),
]

# %%
training_history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
)
history_dict = training_history.history
# Out:
# Epoch 1/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 2.0143 - temperature: 0.0998
# Epoch 1: val_loss improved from None to 2.34065, saving model to checkpoints/clip_resnet50_best.weights.h5
#
# Epoch 1: finished saving model to checkpoints/clip_resnet50_best.weights.h5
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 201s 71ms/step - loss: 1.9269 - temperature: 0.0996 - val_loss: 2.3406 - val_temperature: 0.0996 - learning_rate: 1.0000e-05
# Epoch 2/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.7580 - temperature: 0.0995
# Epoch 2: val_loss did not improve from 2.34065
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 166s 66ms/step - loss: 1.7405 - temperature: 0.0993 - val_loss: 2.3932 - val_temperature: 0.0993 - learning_rate: 1.0000e-05
# Epoch 3/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.6983 - temperature: 0.0991
# Epoch 3: val_loss improved from 2.34065 to 2.28007, saving model to checkpoints/clip_resnet50_best.weights.h5
#
# Epoch 3: finished saving model to checkpoints/clip_resnet50_best.weights.h5
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 167s 67ms/step - loss: 1.6897 - temperature: 0.0990 - val_loss: 2.2801 - val_temperature: 0.0990 - learning_rate: 1.0000e-05
# Epoch 4/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.6717 - temperature: 0.0988
# Epoch 4: val_loss did not improve from 2.28007
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 165s 66ms/step - loss: 1.6622 - temperature: 0.0986 - val_loss: 2.3176 - val_temperature: 0.0986 - learning_rate: 1.0000e-05
# Epoch 5/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.6472 - temperature: 0.0985
# Epoch 5: val_loss did not improve from 2.28007
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 165s 66ms/step - loss: 1.6421 - temperature: 0.0983 - val_loss: 2.3821 - val_temperature: 0.0983 - learning_rate: 1.0000e-05

# %% [markdown]
# ## Save current training

# %%
drive.mount('/content/drive')

SAVE_DIR = "/content/drive/MyDrive/clip_histopathology_v6"
os.makedirs(SAVE_DIR, exist_ok=True)

# 1. Save model weights
weights_path = os.path.join(SAVE_DIR, "clip_resnet50_v6.weights.h5")
model.save_weights(weights_path)

# 2. Save split
split = {
    "train_records": train_records.tolist() if isinstance(train_records, np.ndarray) else list(train_records),
    "train_labels": train_labels.tolist() if isinstance(train_labels, np.ndarray) else list(train_labels),
    "val_records": val_records.tolist() if isinstance(val_records, np.ndarray) else list(val_records),
    "val_labels": val_labels.tolist() if isinstance(val_labels, np.ndarray) else list(val_labels),
    "test_records": test_records.tolist() if isinstance(test_records, np.ndarray) else list(test_records),
    "test_labels": test_labels.tolist() if isinstance(test_labels, np.ndarray) else list(test_labels),
}

with open(os.path.join(SAVE_DIR, "split.json"), "w") as f:
    json.dump(split, f)

# 3. Save training history if available
if "history" in globals():
    with open(os.path.join(SAVE_DIR, "history.json"), "w") as f:
        json.dump(history_dict, f)

print("Saved snapshot to:", SAVE_DIR)
print(" - weights: clip_resnet50_v6.weights.h5")
print(" - split: split.json")
if "history" in globals():
    print(" - training history: history.json")
# Out:
# Mounted at /content/drive
# Saved snapshot to: /content/drive/MyDrive/clip_histopathology_v6
#  - weights: clip_resnet50_v6.weights.h5
#  - split: split.json

# %% [markdown]
# ## Load previous training

# %%
drive.mount('/content/drive')

SAVE_DIR = "/content/drive/MyDrive/clip_histopathology_v6"

# 1. Load split
with open(os.path.join(SAVE_DIR, "split.json"), "r") as f:
    split = json.load(f)

train_records = np.array(split["train_records"])
train_labels = np.array(split["train_labels"])
val_records = np.array(split["val_records"])
val_labels = np.array(split["val_labels"])
test_records = np.array(split["test_records"])
test_labels = np.array(split["test_labels"])

# 2. Rebuild tf.data datasets
train_ds = tf.data.Dataset.from_tensor_slices((train_records, train_labels))
train_ds = train_ds.shuffle(len(train_records), seed=SEED)
train_ds = train_ds.map(preprocess_training_example, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.batch(BATCH_SIZE)
train_ds = train_ds.prefetch(AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val_records, val_labels))
val_ds = val_ds.map(preprocess_validation_example, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.batch(BATCH_SIZE)
val_ds = val_ds.prefetch(AUTOTUNE)

# If you have a separate test preprocessing function that returns (image, class_id),
# rebuild test_ds with that later. Otherwise keep raw split loaded and rebuild as needed.

# 3. Recreate model
model = CLIPModel(image_backbone, text_backbone, embed_dim=EMBED_DIM)
model.compile(optimizer=optimizer)

# 4. Build model once before loading weights
batch = next(iter(train_ds))
images, token_dict = batch
_ = model((images[:1], {k: v[:1] for k, v in token_dict.items()}), training=False)

# 5. Load weights
weights_path = os.path.join(SAVE_DIR, "clip_resnet50_v6.weights.h5")
model.load_weights(weights_path)

# 6. Load training history if available
history_path = os.path.join(SAVE_DIR, "history.json")
if os.path.exists(history_path):
    with open(history_path, "r") as f:
        history_dict = json.load(f)
else:
    history_dict = None

print("Loaded snapshot from:", SAVE_DIR)
print("Train/Val/Test sizes:", len(train_records), len(val_records), len(test_records))
print("Weights loaded successfully.")
if history_dict is not None:
    print("History loaded successfully.")

# %% [markdown]
# # Results

# %% [markdown]
# ## Visualization of the results

# %% [markdown]
# ### Train / Validation loss

# %%
plt.figure(figsize=(8, 5))
plt.plot(history_dict["loss"], label="train_loss")
plt.plot(history_dict["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Training VS Validation loss")
plt.show()

# %% [markdown]
# ### Zero shot classification

# %% [markdown]
# Visualize a few predictions made by the model (zero-shot classification)

# %%
# Average the multiple prompts used for training per class to get the text embeddings centroid
def build_class_text_embeddings():
    class_text_embeddings = []

    for class_name in class_names:
        prompts = [template.format(class_name) for template in PROMPT_TEMPLATES]
        token_dict = text_preprocessor(tf.constant(prompts))

        emb = model.encode_text(token_dict, training=False)

        # Compute mean to get centroid embeddings across all prompts
        class_emb = tf.reduce_mean(emb, axis=0)
        class_emb = tf.math.l2_normalize(class_emb, axis=-1)

        class_text_embeddings.append(class_emb)

    return tf.stack(class_text_embeddings, axis=0)

class_text_emb = build_class_text_embeddings()

# %%
# Quick test with a single, random image
idx = np.random.randint(len(val_records))

image_path = val_records[idx]
true_label = val_labels[idx]

image = load_image(image_path) # (IMG_SIZE, IMG_SIZE, 3)
image_batch = tf.expand_dims(image, axis=0) # (1, IMG_SIZE, IMG_SIZE, 3)

imgage_embeddings = model.encode_image(image_batch, training=False) # (1, EMBED_DIM)
# Dot product to compute cosune similarity to classes
scores = tf.matmul(imgage_embeddings, class_text_emb, transpose_b=True).numpy()[0]

# Takes highest similiarity score as prediction
pred_label = np.argmax(scores)

# Print prediction values
print("Image path: ", image_path)
print("True label: ", true_label)
print("Predicted label: ", pred_label)
print()
print("Scores:")
for cname, score in zip(class_names, scores):
    print(f"{cname:10s} -> {score:.4f}")
print()

# Plot image
plt.figure(figsize=(5,5))

imgage_show = image.numpy()
imgage_show = imgage_show[..., ::-1]   # BGR -> RGB
imgage_show = imgage_show - imgage_show.min()
imgage_show = imgage_show / (imgage_show.max() + 1e-8)

plt.imshow(imgage_show)
plt.title(f"True: {index_to_name[true_label]}\nPred: {index_to_name[pred_label]}")
plt.axis("off")
plt.show()
# Out:
# Image path:  /kaggle/input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_n/lungn3881.jpeg
# True label:  0
# Predicted label:  0
#
# Scores:
# benign lung tissue -> 0.2800
# lung adenocarcinoma -> 0.0889
# lung squamous cell carcinoma -> -0.3049
# benign colon tissue -> 0.2109
# colon adenocarcinoma -> 0.0323

# %% [markdown]
# #### Accuracy and Macro F1 metrics

# %%
test_preds = []
test_true = []
test_images = []

for images, true_class_ids in test_ds:
  image_embeddings = model.encode_image(images, training=False)
  scores = tf.matmul(image_embeddings, class_text_emb, transpose_b=True)
  pred_class_ids = tf.argmax(scores, axis=1, output_type=tf.int32)

  test_preds.extend(pred_class_ids.numpy().tolist())
  test_true.extend(true_class_ids.numpy().tolist())
  test_images.extend(images.numpy())

test_preds = np.array(test_preds, dtype=np.int32)
test_true = np.array(test_true, dtype=np.int32)
test_images = np.array(test_images)

acc = (test_preds == test_true).mean()
macro_f1 = f1_score(test_true, test_preds, average="macro")
print("Test accuracy:", acc)
print("Test macro F1:", macro_f1)
# Out:
# Test accuracy: 0.5748
# Test macro F1: 0.5332176463042548

# %% [markdown]
# #### Recall metrics

# %% [markdown]
# Evaluation metrics chose based on CLIP's paper:
# - R@1 (Recall at 1): Measures the percentage of queries where the single top-ranked result (the most relevant item) is the correct one.
# - R@5 (Recall at 5): Measures the percentage of queries where the correct result is found within the top 5 ranked items.

# %%
# Create test retrieval dataset to visualize model results

def preprocess_retrieval_example(img_path, label):
    image = load_image(img_path)
    return image, label

test_retrieval_ds = tf.data.Dataset.from_tensor_slices((test_records, test_labels))
test_retrieval_ds = test_retrieval_ds.map(
    preprocess_retrieval_example,
    num_parallel_calls=AUTOTUNE
)
test_retrieval_ds = test_retrieval_ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %%
test_image_embeddings = []
test_text_embeddings = []
test_label_ids = []

def make_test_batch_prompt(true_class_ids):
  return [
        tf.strings.format(
            "A histopathology image of {}.",
            class_names_tf[tf.cast(class_id, tf.int32)]
        ).numpy().decode('utf-8')
        for class_id in true_class_ids.numpy()]

for images, true_class_ids in test_ds:
    token_dict = text_preprocessor(make_test_batch_prompt(true_class_ids))

    image_embeddings = model.encode_image(images, training=False)
    text_embeddings = model.encode_text(token_dict, training=False)

    test_image_embeddings.append(image_embeddings.numpy())
    test_text_embeddings.append(text_embeddings.numpy())
    test_label_ids.extend(true_class_ids.numpy().tolist())

test_image_embeddings = np.concatenate(test_image_embeddings, axis=0)
test_text_embeddings = np.concatenate(test_text_embeddings, axis=0)
test_label_ids = np.array(test_label_ids, dtype=np.int32)
# Out:
# Test image embeddings shape: (2500, 256)
# Test text embeddings shape: (2500, 256)

# %%
ranks_i2t = []
ranks_t2i = []

# Normalize embeddings
normalized_test_image_embeddings = test_image_embeddings / np.linalg.norm(test_image_embeddings, axis=1, keepdims=True)
normalized_test_text_embeddings = test_text_embeddings / np.linalg.norm(test_text_embeddings, axis=1, keepdims=True)

# Similarity matrix
S = normalized_test_image_embeddings @ normalized_test_text_embeddings.T

# Image -> Text
for i in range(S.shape[0]):
    order = np.argsort(-S[i])  # texts ranked for image i
    correct_texts = np.where(test_label_ids == test_label_ids[i])[0]
    rank = min(np.where(order == j)[0][0] for j in correct_texts)
    ranks_i2t.append(rank)

# Text -> Image
for j in range(S.shape[1]):
    order = np.argsort(-S[:, j])  # images ranked for text j
    correct_images = np.where(test_label_ids == test_label_ids[j])[0]
    rank = min(np.where(order == i)[0][0] for i in correct_images)
    ranks_t2i.append(rank)

def recall_at_k(ranks, k):
    return np.mean(np.array(ranks) < k)

print("I→T R@1:", recall_at_k(ranks_i2t, 1))
print("I→T R@5:", recall_at_k(ranks_i2t, 5))

print("T→I R@1:", recall_at_k(ranks_t2i, 1))
print("T→I R@5:", recall_at_k(ranks_t2i, 5))

print("Mean rank I→T:", np.mean(ranks_i2t))
print("Median rank I→T:", np.median(ranks_i2t))
# Out:
# I→T R@1: 0.3896
# I→T R@5: 0.3896
# T→I R@1: 0.2
# T→I R@5: 0.4
# Mean rank I→T: 625.0
# Median rank I→T: 500.0

# %%
n_show = 8
idxs = np.random.choice(len(test_true), size=n_show, replace=False)

plt.figure(figsize=(16, 8))
for i, idx in enumerate(idxs):
    plt.subplot(2, 4, i + 1)

    img = test_images[idx]
    img = img[..., ::-1]
    img = img - img.min()
    img = img / (img.max() + 1e-8)

    true_label = index_to_name[int(test_true[idx])]
    pred_label = index_to_name[int(test_preds[idx])]

    plt.imshow(img)
    plt.title(f"T: {true_label}\nP: {pred_label}")
    plt.axis("off")

plt.tight_layout()
plt.show()

print("Test accuracy:", acc)
print("Test macro F1:", macro_f1)

print("I→T R@1:", recall_at_k(ranks_i2t, 1))
print("I→T R@5:", recall_at_k(ranks_i2t, 5))

print("T→I R@1:", recall_at_k(ranks_t2i, 1))
print("T→I R@5:", recall_at_k(ranks_t2i, 5))

print("Mean rank I→T:", np.mean(ranks_i2t))
print("Median rank I→T:", np.median(ranks_i2t))
# Out:
# Test accuracy: 0.5748
# Test macro F1: 0.5332176463042548
# I→T R@1: 0.3896
# I→T R@5: 0.3896
# T→I R@1: 0.2
# T→I R@5: 0.4
# Mean rank I→T: 625.0
# Median rank I→T: 500.0

# %% [markdown]
# ### Confusion matrix

# %%
cm = confusion_matrix(test_true, test_preds, labels=list(range(len(class_names))))

fig, ax = plt.subplots(figsize=(7,7))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(ax=ax, cmap="Blues", xticks_rotation=45)

plt.title("Test Confusion Matrix")
plt.show()

# %% [markdown]
# ### UMAP visualization

# %%
reducer = umap.UMAP(
    n_neighbors=15,
    min_dist=0.1,
    metric="cosine",
    random_state=42
)

emb_2d = reducer.fit_transform(test_image_embeddings)

print(emb_2d.shape)
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# (2500, 2)

# %%
plt.figure(figsize=(8,6))

for i, name in index_to_name.items():
    idx = test_true == i
    plt.scatter(
        emb_2d[idx,0],
        emb_2d[idx,1],
        s=8,
        alpha=0.6,
        label=name
    )

plt.legend()
plt.title("UMAP of Image Embeddings")
plt.xlabel("UMAP-1")
plt.ylabel("UMAP-2")
plt.show()
